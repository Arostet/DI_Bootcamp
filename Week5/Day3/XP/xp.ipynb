# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data = {
    'Price': [1, 2, 3, 4, 5],
    'Demand': [5, 4, 3, 2, 1]
}
data
# Out:
# {'Price': [1, 2, 3, 4, 5], 'Demand': [5, 4, 3, 2, 1]}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Price  Demand
# 0      1       5
# 1      2       4
# 2      3       3
# 3      4       2
# 4      5       1

# %%
df.plot(x="Price", y="Demand", title="Product Demand vs Price", xlabel="Price",ylabel="Demand")
# Out:
# <Axes: title={'center': 'Product Demand vs Price'}, xlabel='Price', ylabel='Demand'>

# %%
data2 = { 
    "Age": [1, 2, 3, 4, 5],
    "Height": [75, 80, 88, 95, 105] 
          } 
data
# Out:
# {'Age': [1, 2, 3, 4, 5], 'Height': [75, 80, 88, 95, 105]}

# %%
plt.df_ah = pd.DataFrame(data2)
plt.df_ah.plot(x="Age", y="Height",xlabel="Age(years)", ylabel="Height(cm)", title="Children’s Height vs Age", kind="scatter")
plt.savefig("product_demand_vs_price.png", dpi=300)

# %%
data3 = {
    "x" : np.linspace(-10, 10, 1000),
    "y1" : np.sin(x),
    "y2" : np.cos(x)
}

# %%
df_xyy = pd.DataFrame(data3)
df_xyy.plot(x="y2", )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df_xyy = pd.DataFrame(data3)
#       2 df_xyy.plot(x="y2", y="y1", kind="lineplot")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# ...

# %%
chipo = pd.read_csv("./chipotle.tsv", delimiter='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 chipo = pd.read_csv("./chipotle.tsv", delimiter='\t')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...
